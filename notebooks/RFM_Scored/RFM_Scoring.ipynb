# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import pymssql
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid')

def get_connection():
    return pymssql.connect(
        server='localhost',
        port='1433',
        user='sa',
        password='Poor@b19',
        database='RFM_Analysis'
    )

engine = create_engine('mssql+pymssql://', creator=get_connection)
print("Connected")
# Out:
# Connected

# %%
df_rfm = pd.read_sql("SELECT * FROM dbo.Distributed_scored", engine)

print(f"Data loaded")
print(f"   Total customers : {len(df_rfm):,}")
print(f"   Columns         : {df_rfm.columns.tolist()}")

df_rfm.head(10)
# Out:
# Data loaded
#    Total customers : 5,863
#    Columns         : ['Customer_ID', 'Recency', 'Frequency', 'Monetary', 'R_Score', 'F_Score', 'M_Score', 'RFM_Sum', 'RFM_Segment']
#    Customer_ID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0        12357       33          3  18287.66        4        2        5
# 1        12358        1          5   3887.07        5        2        3
# 2        12372       71          3   1298.04        4        2        2
# 3        12375       10          2    457.50        5        1        1
# 4        12389      402          3   1433.33        2        2        2
# 5        12390       79          1    549.84        4        1        1
# 6        12407       49          5   1708.12        4        2        2
# 7        12408       32          8   4340.77        4        3        3
# 8        12422       95         15   4173.35        4        4        3
# 9        12425       78          2   1741.41        4        1        2
#
# ...

# %%
df_rfm.to_csv('../data/processed/Distributed_scored.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_rfm.to_csv('../data/processed/Distributed_scored.csv', index=False)
#
# File ~/Downloads/anaconda3/envs/venv/lib/python3.13/site-packages/pandas/core/generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
#    3989     path_or_buf,
#    3990     lineterminator=lineterminator,
#    3991     sep=sep,
# ...
