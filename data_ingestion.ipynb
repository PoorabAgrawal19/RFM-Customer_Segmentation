# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pymssql

print("Libraries imported!")
# Out:
# Libraries imported!

# %%
def get_connection():
    return pymssql.connect(
        server='localhost',
        port='1433',
        user='sa',
        password='Poor@b19',
        database='RFM_Analysis'
    )

engine = create_engine('mssql+pymssql://', creator=get_connection)

with engine.connect() as conn:
    print("Connected to MSSQL !")
# Out:
# Connected to MSSQL !

# %%
df = pd.read_csv('/Users/poorabagrawal/Desktop/RFM_Analysis/online_retail_II.csv', encoding='latin-1')
df.columns = df.columns.str.replace(' ', '_')

print(f" Dataset loaded!")
print(f"   Rows    : {len(df):,}")
print(f"   Columns : {df.columns.tolist()}")
# Out:
#  Dataset loaded!
#    Rows    : 1,067,371
#    Columns : ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'Customer_ID', 'Country']

# %%
df.to_sql(
    name='retail_raw_new',
    con=engine,
    if_exists='replace',
    index=False,
    schema='dbo'
)
print("Data pushed to SQL Server!")
print(f"   Rows : {len(df):,}")
# Out:
# Data pushed to SQL Server!
#    Rows : 1,067,371
